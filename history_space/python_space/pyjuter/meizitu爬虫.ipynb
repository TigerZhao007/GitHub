# %%
# -*- coding: utf-8 -*-
from bs4 import BeautifulSoup
import requests
from lxml import etree
import pandas as pd
from selenium import webdriver  
import re
import urllib
import time
import os

# %%
# 获取所有图片链接url_list
'''
browser = webdriver.PhantomJS(executable_path="D:/Python/selenium/webdriver/phantomjs/bin/phantomjs.exe")  
browser.get('http://www.mzitu.com/')
html = browser.page_source
selector = etree.HTML(html)
#pagenum = selector.xpath('/html/body/div[2]/div[1]/div[2]/nav/div/a[4]/@href')[0].strip('http://www.mzitu.com/page/').strip('/')

'''

url_list = ['http://www.mzitu.com/']+['http://www.mzitu.com/page/%s/'%(str(num)) for num in range(2,int(180)+1)]

# %%
# 设置图片存储路径
path_info = 'E:\Downloads\picture\data_information'
path = 'E:/Downloads/picture/妹子图meizitu/'
# 创建文件夹
try:
    os.mkdir(path)
except:
    pass
# @brief 保存图片  # url : 图片url # addr  : 保存的地址
def save_picture(url,addr,name,num):
    headers = { 'User-Agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) ' 'Chrome/65.0.3325.181 Safari/537.36',
                 'Referer': "http://www.mzitu.com"}
    picture = requests.get(url,headers=headers,stream=True)
    path = addr + name + str(num)+ '.jpg'
    with open(path, 'wb')as f:
        f.write(picture.content)
        #print("正在保存{}第{}张".format(self.girl_name, img_name))
        f.close()

# %%
# 详情信息info
item = {
    'name':'标题',
    'link':'链接',
    'date':'发布日期',
    'data':'浏览数量'
}
item = pd.DataFrame.from_dict(item,orient='index').T

# %%
# 获取详情信息info
browser = webdriver.PhantomJS(executable_path="D:/Python/selenium/webdriver/phantomjs/bin/phantomjs.exe")  
item_list = pd.DataFrame()
for url in url_list:
    print('--------------------------------------------------------')
    print('正在加载%s信息'%(url))
    time.sleep(3)
    browser.get(url)
    data = browser.page_source
    soup =  BeautifulSoup(data,'lxml')
    try:
        lis1 = soup.find('div',attrs={'class':'main'}).find('ul',attrs={'id':'pins'}).find_all('li')
    except:
        lis1 = []
        print('加载失败')
    for lis in lis1: 
        try:
            item['link'] = lis.find('a')['href'].strip(' ')
            item['name'] = lis.find('img')['alt'].strip(' ').replace("!",'').replace("！",'').replace(",",'').replace("，",'').replace(" ",'').replace(" ",'').replace("？",'').replace("\"",'')
            item['date'] = lis.find_all('span')[1].getText().strip('发布').strip(' ')
            item['data'] = lis.find_all('span')[2].getText().strip('浏览(').strip(')').strip('次').strip(' ')
            item_list = item_list.append(item)
        except:
            print('加载失败')
# Out:
# D:\Python\lib\site-packages\selenium\webdriver\phantomjs\webdriver.py:49: UserWarning: Selenium support for PhantomJS has been deprecated, please use headless versions of Chrome or Firefox instead
#   warnings.warn('Selenium support for PhantomJS has been deprecated, please use headless '
# --------------------------------------------------------
# 正在加载http://www.mzitu.com/信息
# --------------------------------------------------------
# 正在加载http://www.mzitu.com/page/2/信息
# --------------------------------------------------------
# 正在加载http://www.mzitu.com/page/3/信息
# --------------------------------------------------------
# 正在加载http://www.mzitu.com/page/4/信息
# --------------------------------------------------------
# 正在加载http://www.mzitu.com/page/5/信息
# --------------------------------------------------------
# 正在加载http://www.mzitu.com/page/6/信息
# --------------------------------------------------------
# 正在加载http://www.mzitu.com/page/7/信息
# --------------------------------------------------------
# 正在加载http://www.mzitu.com/page/8/信息
# --------------------------------------------------------
# 正在加载http://www.mzitu.com/page/9/信息
# --------------------------------------------------------
# 正在加载http://www.mzitu.com/page/10/信息
# --------------------------------------------------------
# 正在加载http://www.mzitu.com/page/11/信息
# --------------------------------------------------------
# 正在加载http://www.mzitu.com/page/12/信息
# --------------------------------------------------------
# 正在加载http://www.mzitu.com/page/13/信息
# --------------------------------------------------------
# 正在加载http://www.mzitu.com/page/14/信息
# --------------------------------------------------------
# 正在加载http://www.mzitu.com/page/15/信息
# --------------------------------------------------------
# 正在加载http://www.mzitu.com/page/16/信息
# --------------------------------------------------------
# 正在加载http://www.mzitu.com/page/17/信息
# --------------------------------------------------------
# 正在加载http://www.mzitu.com/page/18/信息
# --------------------------------------------------------
# 正在加载http://www.mzitu.com/page/19/信息
# --------------------------------------------------------
# 正在加载http://www.mzitu.com/page/20/信息
# --------------------------------------------------------
# 正在加载http://www.mzitu.com/page/21/信息
# --------------------------------------------------------
# 正在加载http://www.mzitu.com/page/22/信息
# --------------------------------------------------------
# 正在加载http://www.mzitu.com/page/23/信息
# --------------------------------------------------------
# 正在加载http://www.mzitu.com/page/24/信息
# --------------------------------------------------------
# 正在加载http://www.mzitu.com/page/25/信息
# --------------------------------------------------------
# 正在加载http://www.mzitu.com/page/26/信息
# --------------------------------------------------------
# 正在加载http://www.mzitu.com/page/27/信息
# --------------------------------------------------------
# 正在加载http://www.mzitu.com/page/28/信息
# --------------------------------------------------------
# 正在加载http://www.mzitu.com/page/29/信息
# --------------------------------------------------------
# 正在加载http://www.mzitu.com/page/30/信息
# --------------------------------------------------------
# 正在加载http://www.mzitu.com/page/31/信息
# --------------------------------------------------------
# 正在加载http://www.mzitu.com/page/32/信息
# --------------------------------------------------------
# 正在加载http://www.mzitu.com/page/33/信息
# --------------------------------------------------------
# 正在加载http://www.mzitu.com/page/34/信息
# --------------------------------------------------------
# 正在加载http://www.mzitu.com/page/35/信息
# --------------------------------------------------------
# 正在加载http://www.mzitu.com/page/36/信息
# --------------------------------------------------------
# 正在加载http://www.mzitu.com/page/37/信息
# --------------------------------------------------------
# 正在加载http://www.mzitu.com/page/38/信息
# --------------------------------------------------------
# 正在加载http://www.mzitu.com/page/39/信息
# --------------------------------------------------------
# 正在加载http://www.mzitu.com/page/40/信息
# --------------------------------------------------------
# 正在加载http://www.mzitu.com/page/41/信息
# --------------------------------------------------------
# 正在加载http://www.mzitu.com/page/42/信息
# --------------------------------------------------------
# 正在加载http://www.mzitu.com/page/43/信息
# --------------------------------------------------------
# 正在加载http://www.mzitu.com/page/44/信息
# --------------------------------------------------------
# 正在加载http://www.mzitu.com/page/45/信息
# --------------------------------------------------------
# 正在加载http://www.mzitu.com/page/46/信息
# --------------------------------------------------------
# 正在加载http://www.mzitu.com/page/47/信息
# --------------------------------------------------------
# 正在加载http://www.mzitu.com/page/48/信息
# --------------------------------------------------------
# 正在加载http://www.mzitu.com/page/49/信息
# --------------------------------------------------------
# 正在加载http://www.mzitu.com/page/50/信息
# --------------------------------------------------------
# 正在加载http://www.mzitu.com/page/51/信息
# --------------------------------------------------------
# 正在加载http://www.mzitu.com/page/52/信息
# --------------------------------------------------------
# 正在加载http://www.mzitu.com/page/53/信息
# --------------------------------------------------------
# 正在加载http://www.mzitu.com/page/54/信息
# --------------------------------------------------------
# 正在加载http://www.mzitu.com/page/55/信息
# --------------------------------------------------------
# 正在加载http://www.mzitu.com/page/56/信息
# --------------------------------------------------------
# 正在加载http://www.mzitu.com/page/57/信息
# --------------------------------------------------------
# 正在加载http://www.mzitu.com/page/58/信息
# --------------------------------------------------------
# 正在加载http://www.mzitu.com/page/59/信息
# --------------------------------------------------------
# 正在加载http://www.mzitu.com/page/60/信息
# --------------------------------------------------------
# 正在加载http://www.mzitu.com/page/61/信息
# --------------------------------------------------------
# 正在加载http://www.mzitu.com/page/62/信息
# --------------------------------------------------------
# 正在加载http://www.mzitu.com/page/63/信息
# --------------------------------------------------------
# 正在加载http://www.mzitu.com/page/64/信息
# --------------------------------------------------------
# 正在加载http://www.mzitu.com/page/65/信息
# --------------------------------------------------------
# 正在加载http://www.mzitu.com/page/66/信息
# --------------------------------------------------------
# 正在加载http://www.mzitu.com/page/67/信息
# --------------------------------------------------------
# 正在加载http://www.mzitu.com/page/68/信息
# --------------------------------------------------------
# 正在加载http://www.mzitu.com/page/69/信息
# --------------------------------------------------------
# 正在加载http://www.mzitu.com/page/70/信息
# --------------------------------------------------------
# 正在加载http://www.mzitu.com/page/71/信息
# --------------------------------------------------------
# 正在加载http://www.mzitu.com/page/72/信息
# --------------------------------------------------------
# 正在加载http://www.mzitu.com/page/73/信息
# --------------------------------------------------------
# 正在加载http://www.mzitu.com/page/74/信息
# --------------------------------------------------------
# 正在加载http://www.mzitu.com/page/75/信息
# --------------------------------------------------------
# 正在加载http://www.mzitu.com/page/76/信息
# --------------------------------------------------------
# 正在加载http://www.mzitu.com/page/77/信息
# --------------------------------------------------------
# 正在加载http://www.mzitu.com/page
# 0         Beautyleg美腿写真No.993Miki  http://www.mzitu.com/26749  2013-06-01
# 0   Beautyleg美腿写真No.994AnitaPart2  http://www.mzitu.com/26736  2013-06-01
# 0        Beautyleg美腿写真No.994Anita  http://www.mzitu.com/26723  2013-06-01
# 0         Beautyleg美腿写真No.995Abby  http://www.mzitu.com/26712  2013-06-01
# 0        Beautyleg美腿写真No.996Cindy  http://www.mzitu.com/26698  2013-06-01
# 0         Beautyleg美腿写真No.997Dora  http://www.mzitu.com/26685  2013-06-01
#
#          data
# 0     763,557
# 0     615,811
# 0   1,548,964
# 0     623,262
# 0     255,442
# 0   1,813,004
# 0   1,434,083
# 0     670,404
# 0     680,419
# 0   1,329,080
# 0     610,549
# 0   1,374,558
# 0     856,162
# 0     382,160
# 0   2,671,783
# 0   1,247,740
# 0     854,243
# 0   1,834,940
# 0   1,352,070
# 0     932,388
# 0   1,377,836
# 0     763,192
# 0     632,395
# 0     817,690
# 0     547,090
# 0     620,181
# 0   1,394,560
# 0     693,586
# 0     847,348
# 0   1,093,588
# ..        ...
# 0   1,077,226
# 0     209,317
# 0     415,975
# 0     298,658
# 0     259,696
# 0     136,196
# 0      93,608
# 0     120,990
# 0      93,488
# 0      87,160
# 0     100,074
# 0     135,114
# 0      71,787
# 0     111,855
# 0      93,891
# 0     116,200
# 0     101,578
# 0      54,786
# 0      89,745
# 0     109,301
# 0      79,285
# 0      88,311
# 0     131,266
# 0      77,660
# 0     100,279
# 0     137,709
# 0      97,704
# 0      60,541
# 0     194,084
# 0     156,530
#
# [2041 rows x 4 columns]

# %%
# 获取详情页图片
driver = webdriver.PhantomJS(executable_path="D:/Python/selenium/webdriver/phantomjs/bin/phantomjs.exe")  
item_flase = pd.DataFrame()
for i in range(1679,len(item_list)): 
    url1 = item_list['link'].iloc[i]
    name = item_list['name'].iloc[i]
    print('---------------------------------------------')
    print('正在加载图片%s'%(url1))
    j = 1
    try:
        driver.get(url1)
        html = driver.page_source
        selector = etree.HTML(html)
        maxnum = selector.xpath('/html/body/div[2]/div[1]/div[4]/a[5]/span/text()')[0]
        url_list = ['%s/%s'%(url1,str(num)) for num in range(1,int(maxnum)+1)]
        for url2 in url_list:
            driver.get(url2)
            time.sleep(1)
            html = driver.page_source
            selector = etree.HTML(html)
            pic_urls = selector.xpath('/html/body/div[2]/div[1]/div[3]/p/a/img/@src')
            save_picture(pic_urls[0],path,name,j )
            j += 1
    except:
        item_flase = item_flase.append(item_list.iloc[i,:])
        print('加载失败')
# Out:
# D:\Python\lib\site-packages\selenium\webdriver\phantomjs\webdriver.py:49: UserWarning: Selenium support for PhantomJS has been deprecated, please use headless versions of Chrome or Firefox instead
#   warnings.warn('Selenium support for PhantomJS has been deprecated, please use headless '
# ---------------------------------------------
# 正在加载图片http://www.mzitu.com/52231
# 加载失败
# ---------------------------------------------
# 正在加载图片http://www.mzitu.com/52180
# 加载失败
# ---------------------------------------------
# 正在加载图片http://www.mzitu.com/52136
